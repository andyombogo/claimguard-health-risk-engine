# %% [markdown]
# # 02 Rule Engine Prototype
#
# Use this notebook to prototype rule logic for duplicate patterns, abnormal billing, diagnosis-treatment mismatch checks, document completeness, and provider history signals.
